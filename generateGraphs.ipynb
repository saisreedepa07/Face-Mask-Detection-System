# %% [markdown]
# Code Executed in google collab to genarate graphs

# %%
import pandas as pd
df = pd.read_csv("/content/results.csv")

# %%
df
# Out:
#                    epoch        train/box_loss        train/obj_loss  \
# 0                      0              0.104040              0.060046
# 1                      1              0.077920              0.049368
# 2                      2              0.074933              0.041190
# 3                      3              0.069463              0.036247
# 4                      4              0.058778              0.037873
# ..                   ...                   ...                   ...
# 95                    95              0.019374              0.020310
# 96                    96              0.019450              0.021551
# 97                    97              0.019167              0.019800
# 98                    98              0.018790              0.020725
# 99                    99              0.019506              0.021053
#
#           train/cls_loss     metrics/precision        metrics/recall  \
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df['      train/box_loss'])

# %%
plt.plot(df['      train/obj_loss'])

# %%
plt.plot(df['      train/cls_loss'])

# %%
df
# Out:
#                    epoch        train/box_loss        train/obj_loss  \
# 0                      0              0.104040              0.060046
# 1                      1              0.077920              0.049368
# 2                      2              0.074933              0.041190
# 3                      3              0.069463              0.036247
# 4                      4              0.058778              0.037873
# ..                   ...                   ...                   ...
# 95                    95              0.019374              0.020310
# 96                    96              0.019450              0.021551
# 97                    97              0.019167              0.019800
# 98                    98              0.018790              0.020725
# 99                    99              0.019506              0.021053
#
#           train/cls_loss     metrics/precision        metrics/recall  \
# ...

# %%
cols = list(df.columns)

# %%
cols
# Out:
# ['               epoch',
#  '      train/box_loss',
#  '      train/obj_loss',
#  '      train/cls_loss',
#  '   metrics/precision',
#  '      metrics/recall',
#  '     metrics/mAP_0.5',
#  'metrics/mAP_0.5:0.95',
#  '        val/box_loss',
#  '        val/obj_loss',
#  '        val/cls_loss',
#  '               x/lr0',
#  '               x/lr1',
#  '               x/lr2']

# %%
fig, axs = plt.subplots(3, 4, figsize=(10, 10))
axs[0, 0].plot(df[cols[2]])
axs[0, 1].plot(df[cols[3]])
axs[0, 2].plot(df[cols[4]])
axs[0, 3].plot(df[cols[5]])
axs[1, 0].plot(df[cols[6]])
axs[1, 1].plot(df[cols[7]])
axs[1, 2].plot(df[cols[8]])
axs[1, 3].plot(df[cols[9]])
axs[2, 0].plot(df[cols[10]])
axs[2, 1].plot(df[cols[11]])
axs[2, 2].plot(df[cols[12]])
axs[2, 3].plot(df[cols[13]])
# axs[3, 0].plot(df[cols[12]])
# axs[3, 1].plot(df[cols[13]])


axs[0, 0].set_title(cols[2])
axs[0, 1].set_title(cols[3])
axs[0, 2].set_title(cols[4])
axs[0, 3].set_title(cols[5])
axs[1, 0].set_title(cols[6])
axs[1, 1].set_title(cols[7])
axs[1, 2].set_title(cols[8])
axs[1, 3].set_title(cols[9])
axs[2, 0].set_title(cols[10])
axs[2, 1].set_title(cols[11])
axs[2, 2].set_title(cols[12])
axs[2, 3].set_title(cols[13])
# axs[3, 0].set_title(cols[12])
# axs[3, 1].set_title(cols[13])

# add overall title and adjust layout
fig.suptitle('yolo v5 graphs')
fig.tight_layout()

plt.show()

# %%
cols[13]
# Out:
# '               x/lr2'

# %%
cols = []
for col in df.columns:
  plt.figure()
  plt.plot(df[col]) 
  plt.title(col)
  if(len(col.split('/'))>1):
    plt.savefig(str(" ".join(col.split('/')))+'.png')
  else:
    plt.savefig(col+".png")

# %%
cols
# Out:
# ['               epoch',
#  '      train/box_loss',
#  '      train/obj_loss',
#  '      train/cls_loss',
#  '   metrics/precision',
#  '      metrics/recall',
#  '     metrics/mAP_0.5',
#  'metrics/mAP_0.5:0.95',
#  '        val/box_loss',
#  '        val/obj_loss',
#  '        val/cls_loss',
#  '               x/lr0',
#  '               x/lr1',
#  '               x/lr2']

# %%
plt.plot(df[cols[4]])
